# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
import bokeh as bk
import datetime

# %matplotlib inline

# %%
pinfo = pd.read_csv('/Users/arnabmondal/Desktop/untitled folder 4/PInfo.csv')
pinfo.head(10)
# Out:
#    Federal Provider Number                        Provider Name  \
# 0                   105870    LIFE CARE CENTER OF CITRUS COUNTY
# 1                    35146  LIFE CARE CENTER OF PARADISE VALLEY
# 2                   225191            LIFE CARE CENTER OF ACTON
# 3                   175439           LIFE CARE CENTER OF SENECA
# 4                   155266       LIFE CARE CENTER OF FORT WAYNE
# 5                   135038            LIFE CARE CENTER OF BOISE
# 6                   106047        LIFE CARE CENTER OF INVERRARY
# 7                   165499           BLACKHAWK LIFE CARE CENTER
# 8                   175281      LIFE CARE CENTER OF KANSAS CITY
# 9                    65255         BRIARWOOD HEALTH CARE CENTER
#
#         Provider Address Provider City Provider State  Provider Zip Code  \
# 0     3325 W JERWAYNE LN       LECANTO             FL              34461
# 1    4065 EAST BELL ROAD       PHOENIX             AZ              85032
# 2         ONE GREAT ROAD         ACTON             MA               1720
# 3    512 COMMUNITY DRIVE        SENECA             KS              66538
# 4    1649 SPY RUN AVENUE    FORT WAYNE             IN              46805
# 5  808 NORTH CURTIS ROAD         BOISE             ID              83706
# 6  4300 ROCK ISLAND ROAD    LAUDERHILL             FL              33319
# 7     73 WEST 5TH STREET     LAKE VIEW             IA              51450
# 8     3231 N 61ST STREET   KANSAS CITY             KS              66104
# 9           1440 VINE ST        DENVER             CO              80206
#
#    Provider Phone Number  Provider SSA County Provider County Name  \
# 0             3527464434                   80               Citrus
# 1             6028670212                   60             Maricopa
# 2             9782639101                   90            Middlesex
# 3             7853363528                  650               Nemaha
# 4             2604228520                   10                Allen
# 5             2083765273                    0                  Ada
# 6             9544856144                   50              Broward
# 7             7126578527                  800                  Sac
# 8             9132991770                  986            Wyandotte
# 9             3033990350                  150               Denver
#
#                            Ownership Type  ...  \
# 0                For profit - Corporation  ...
# 1                For profit - Corporation  ...
# 2                For profit - Corporation  ...
# 3                 For profit - Individual  ...
# 4                For profit - Corporation  ...
# 5  For profit - Limited Liability company  ...
# 6                For profit - Corporation  ...
# 7                 For profit - Individual  ...
# 8                For profit - Corporation  ...
# 9                For profit - Corporation  ...
#
#    Rating Cycle 3 Total Health Score  Total Weighted Health Survey Score  \
# 0                                 88                              60.667
# 1                                 36                              80.667
# 2                                 20                              30.667
# 3                                 16                              12.000
# 4                                 52                             132.167
# 5                                186                             125.000
# 6                                 40                              16.667
# 7                                  8                               8.000
# 8                                 68                              94.000
# 9                                 48                              45.333
#
#   Number of Facility Reported Incidents  Number of Substantiated Complaints  \
# 0                                     0                                   1
# 1                                     0                                   5
# 2                                     0                                   0
# 3                                     0                                   0
# 4                                     2                                  12
# 5                                     0                                  10
# 6                                     0                                   1
# 7                                     1                                   1
# 8                                     0                                   7
# 9                                     0                                   2
#
#   Number of Fines Total Amount of Fines in Dollars  Number of Payment Denials  \
# 0               0                                0                          0
# 1               2                            14794                          0
# 2               0                                0                          0
# 3               0                                0                          0
# 4               1                            23964                          0
# 5               1                            58916                          1
# 6               0                                0                          0
# 7               1                             5700                          0
# 8               0                                0                          0
# 9               0                                0                          0
#
#   Total Number of Penalties  \
# 0                         0
# 1                         2
# 2                         0
# 3                         0
# 4                         1
# 5                         2
# 6                         0
# 7                         1
# 8                         0
# 9                         0
#
#                                             Location  Processing Date
# 0  3325 W JERWAYNE LN LECANTO, FL 34461 (28.87179...       03/01/2020
# 1  4065 EAST BELL ROAD PHOENIX, AZ 85032 (33.6405...       03/01/2020
# 2                                                NaN       03/01/2020
# 3  512 COMMUNITY DRIVE SENECA, KS 66538 (39.84016...       03/01/2020
# 4  1649 SPY RUN AVENUE FORT WAYNE, IN 46805 (41.0...       03/01/2020
# 5  808 NORTH CURTIS ROAD BOISE, ID 83706 (43.6120...       03/01/2020
# 6  4300 ROCK ISLAND ROAD LAUDERHILL, FL 33319 (26...       03/01/2020
# 7  73 WEST 5TH STREET LAKE VIEW, IA 51450 (42.308...       03/01/2020
# 8  3231 N 61ST STREET KANSAS CITY, KS 66104 (39.1...       03/01/2020
# 9  1440 VINE ST DENVER, CO 80206 (39.739, -104.96...       03/01/2020
#
# [10 rows x 86 columns]

# %%
pinfo.shape
# Out:
# (166, 86)

# %%
pinfo.dtypes
# Out:
# Federal Provider Number              int64
# Provider Name                       object
# Provider Address                    object
# Provider City                       object
# Provider State                      object
#                                      ...
# Total Amount of Fines in Dollars     int64
# Number of Payment Denials            int64
# Total Number of Penalties            int64
# Location                            object
# Processing Date                     object
# Length: 86, dtype: object

# %%
frames = [pinfo]
result = pd.concat(frames, sort=False)

# %%
result.shape
# Out:
# (166, 86)

# %%
result.dtypes
# Out:
# Federal Provider Number              int64
# Provider Name                       object
# Provider Address                    object
# Provider City                       object
# Provider State                      object
#                                      ...
# Total Amount of Fines in Dollars     int64
# Number of Payment Denials            int64
# Total Number of Penalties            int64
# Location                            object
# Processing Date                     object
# Length: 86, dtype: object

# %%
result.describe(include='all')
# Out:
#         Federal Provider Number                 Provider Name  \
# count                166.000000                           166
# unique                      NaN                           165
# top                         NaN  LIFE CARE CENTER OF COLUMBIA
# freq                        NaN                             2
# mean              269610.349398                           NaN
# std               166848.402543                           NaN
# min                35126.000000                           NaN
# 25%               106061.000000                           NaN
# 50%               225685.000000                           NaN
# 75%               445250.000000                           NaN
# max               675935.000000                           NaN
#
#               Provider Address Provider City Provider State  \
# count                      166           166            166
# unique                     166           155             30
# top     802 US HIGHWAY 20 EAST          YUMA             TN
# freq                         1             2             26
# mean                       NaN           NaN            NaN
# std                        NaN           NaN            NaN
# min                        NaN           NaN            NaN
# 25%                        NaN           NaN            NaN
# 50%                        NaN           NaN            NaN
# 75%                        NaN           NaN            NaN
# max                        NaN           NaN            NaN
#
#         Provider Zip Code  Provider Phone Number  Provider SSA County  \
# count          166.000000           1.660000e+02           166.000000
# unique                NaN                    NaN                  NaN
# top                   NaN                    NaN                  NaN
# freq                  NaN                    NaN                  NaN
# mean         54591.867470           5.639730e+09           304.415663
# std          29166.044178           2.415541e+09           265.669495
# min           1095.000000           2.082659e+09             0.000000
# 25%          33933.500000           3.547517e+09            90.000000
# 50%          46573.000000           5.152006e+09           230.000000
# 75%          83204.750000           7.816449e+09           470.000000
# max          99352.000000           9.786672e+09           986.000000
#
#        Provider County Name            Ownership Type  ...  \
# count                   166                       166  ...
# unique                  122                         7  ...
# top               Jefferson  For profit - Corporation  ...
# freq                      5                       130  ...
# mean                    NaN                       NaN  ...
# std                     NaN                       NaN  ...
# min                     NaN                       NaN  ...
# 25%                     NaN                       NaN  ...
# 50%                     NaN                       NaN  ...
# 75%                     NaN                       NaN  ...
# max                     NaN                       NaN  ...
#
#         Rating Cycle 3 Total Health Score  Total Weighted Health Survey Score  \
# count                          166.000000                          166.000000
# unique                                NaN                                 NaN
# top                                   NaN                                 NaN
# freq                                  NaN                                 NaN
# mean                            58.632530                           64.188771
# std                            103.886202                           76.987373
# min                              0.000000                            1.333000
# 25%                             16.000000                           18.833500
# 50%                             32.000000                           40.000000
# 75%                             63.000000                           76.666750
# max                            776.000000                          587.667000
#
#        Number of Facility Reported Incidents  \
# count                             166.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                1.078313
# std                                 2.567845
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 1.000000
# max                                22.000000
#
#        Number of Substantiated Complaints Number of Fines  \
# count                          166.000000      166.000000
# unique                                NaN             NaN
# top                                   NaN             NaN
# freq                                  NaN             NaN
# mean                             4.006024        0.500000
# std                              6.060800        0.945484
# min                              0.000000        0.000000
# 25%                              0.000000        0.000000
# 50%                              1.000000        0.000000
# 75%                              5.000000        1.000000
# max                             29.000000        6.000000
#
#        Total Amount of Fines in Dollars Number of Payment Denials  \
# count                        166.000000                 166.00000
# unique                              NaN                       NaN
# top                                 NaN                       NaN
# freq                                NaN                       NaN
# mean                       18608.487952                   0.10241
# std                        59636.225665                   0.32342
# min                            0.000000                   0.00000
# 25%                            0.000000                   0.00000
# 50%                            0.000000                   0.00000
# 75%                         8264.250000                   0.00000
# max                       524885.000000                   2.00000
#
#        Total Number of Penalties  \
# count                 166.000000
# unique                       NaN
# top                          NaN
# freq                         NaN
# mean                    0.602410
# std                     1.122117
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     7.000000
#
#                                                  Location Processing Date
# count                                                 155             166
# unique                                                155               1
# top     8104 TUTTLE AVE SARASOTA, FL 34243 (27.394944,...      03/01/2020
# freq                                                    1             166
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
# [11 rows x 86 columns]

# %%
parties = result.groupby('Number of Facility Reported Incidents')['Rating Cycle 1 Total Number of Health Deficiencies'].sum().sort_values(ascending=False)

parties.plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-accff01ca566> in <module>
# ----> 1 parties = result.groupby('Number of Facility Reported Incidents')['Rating Cycle 1 Total Number of Health Deficiencies'].sum().sort_values(ascending=False)
#       2
#       3 parties.plot(kind="bar")
#
# NameError: name 'result' is not defined
