# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
import bokeh as bk
import datetime

# %matplotlib inline

# %%
df18 = pd.read_csv('/Users/arnabmondal/Desktop/untitled folder 4/w18.csv')
df18.head(10)
# Out:
#      CAND_ID CAND_SURNAME     CAND_FIRSTNAME CAND_ICI  PTY_CD  \
# 0  H8AK00132        SHEIN            DIMITRI        C       1
# 1  H6AK00045        YOUNG           DONALD E        I       2
# 2  H8AK01031       NELSON        THOMAS JOHN        C       2
# 3  H8AK00140       GALVIN              ALYSE        C       3
# 4  H8AL01066      KENNEDY         ROBERT JR.        C       1
# 5  H8AL01082    MCCONNELL      LIZZETTA HILL        C       1
# 6  H4AL01123        BYRNE    BRADLEY ROBERTS        I       2
# 7  H8AL02163     WILLIAMS   AUDRI SCOTT 1955        C       1
# 8  H8AL02197        ISNER        TABITHA KAY        C       1
# 9  H0AL02087         ROBY             MARTHA        I       2
#
#   CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  \
# 0                  DEM     209916.04             0.00   209574.16
# 1                  REP    1234680.31             0.00  1387687.05
# 2                  REP       9288.48             0.00     8821.97
# 3                  IND    1949643.68           154.70  1943398.59
# 4                  DEM     166845.21             0.00   166845.21
# 5                  DEM       5127.00             0.00     6021.00
# 6                  REP    1463187.12         63923.25   834780.43
# 7                  DEM      35365.02             0.00    35210.22
# 8                  DEM     524941.35             0.00   524941.35
# 9                  REP    2573681.12         85734.19  2277448.83
#
#    TRANS_TO_AUTH  ...  SPEC_ELECTION  PRIM_ELECTION  RUN_ELECTION  \
# 0            0.0  ...            NaN            NaN           NaN
# 1            0.0  ...            NaN            NaN           NaN
# 2            0.0  ...            NaN            NaN           NaN
# 3            0.0  ...            NaN            NaN           NaN
# 4            0.0  ...            NaN            NaN           NaN
# 5            0.0  ...            NaN            NaN           NaN
# 6            0.0  ...            NaN            NaN           NaN
# 7            0.0  ...            NaN            NaN           NaN
# 8            0.0  ...            NaN            NaN           NaN
# 9            0.0  ...            NaN            NaN           NaN
#
#    GEN_ELECTION  GEN_ELECTION_PRECENT  OTHER_POL_CMTE_CONTRIB  \
# 0           NaN                   NaN                    0.00
# 1           NaN                   NaN               559861.90
# 2           NaN                   NaN                    0.00
# 3           NaN                   NaN               114833.97
# 4           NaN                   NaN                 7750.00
# 5           NaN                   NaN                    0.00
# 6           NaN                   NaN              1054650.00
# 7           NaN                   NaN                    0.00
# 8           NaN                   NaN                 8605.00
# 9           NaN                   NaN              1672691.24
#
#    POL_PTY_CONTRIB  CVG_END_DT  INDIV_REFUNDS CMTE_REFUNDS
# 0             0.00    12/31/18           0.00          0.0
# 1             0.00    12/31/18        2700.00        500.0
# 2             0.00    12/31/18         600.00          0.0
# 3             0.00    12/31/18        8166.36          0.0
# 4             0.00    12/31/18           0.00          0.0
# 5             0.00     6/30/18           0.00          0.0
# 6           663.98    12/31/18        3050.00          0.0
# 7             0.00     6/30/18           0.00          0.0
# 8             0.00    12/31/18        4796.05       1000.0
# 9          7000.00    12/31/18        6674.00       2000.0
#
# [10 rows x 31 columns]

# %%
df18.shape
# Out:
# (2679, 31)

# %%
df18.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# TTL_RECEIPTS              float64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT        int64
# SPEC_ELECTION             float64
# PRIM_ELECTION             float64
# RUN_ELECTION              float64
# GEN_ELECTION              float64
# GEN_ELECTION_PRECENT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# dtype: object

# %%
df16 = pd.read_csv('/Users/arnabmondal/Desktop/untitled folder 4/w16.csv')
df16.head(10)
# Out:
#      CAND_ID CAND_SURNAME    CAND_FIRSTNAME CAND_ICI  PTY_CD  \
# 0  H6AK00045        YOUNG          DONALD E        I       2
# 1  H6AK00235     LINDBECK             STEVE      NaN       1
# 2  H4AL01123        BYRNE   BRADLEY ROBERTS        I       2
# 3  H6AL01060     YOUNG JR        LARRY DEAN        C       2
# 4  H6AL02167       MATHIS            NATHAN        C       1
# 5  H0AL02087         ROBY            MARTHA        I       2
# 6  H6AL02142    GERRITSON   REBECCA (BECKY)        C       2
# 7  H6AL02159       ROGERS          ROBERT L        C       2
# 8  H4AL03061        SMITH     JESSE TREMAIN        C       1
# 9  H2AL03032       ROGERS    MICHAEL DENNIS        I       2
#
#   CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  \
# 0                  REP    1103561.86              0.0  1322055.12
# 1                  DEM    1102309.77              0.0  1098098.09
# 2                  REP    1367469.77          33152.0  1172750.28
# 3                  REP     178766.88              0.0   178474.16
# 4                  DEM      36844.00              0.0    36844.00
# 5                  REP    1404260.12              0.0  1850535.64
# 6                  REP     206908.19              0.0   206908.19
# 7                  REP      25382.00              0.0    32492.00
# 8                  DEM       9810.00              0.0     7348.00
# 9                  REP    1139022.37              0.0  1071289.42
#
#    TRANS_TO_AUTH  ...  SPEC_ELECTION  PRIM_ELECTION  RUN_ELECTION  \
# 0            0.0  ...            NaN            NaN           NaN
# 1            0.0  ...            NaN            NaN           NaN
# 2            0.0  ...            NaN            NaN           NaN
# 3            0.0  ...            NaN            NaN           NaN
# 4            0.0  ...            NaN            NaN           NaN
# 5            0.0  ...            NaN            NaN           NaN
# 6            0.0  ...            NaN            NaN           NaN
# 7            0.0  ...            NaN            NaN           NaN
# 8            0.0  ...            NaN            NaN           NaN
# 9       167500.0  ...            NaN            NaN           NaN
#
#    GEN_ELECTION  GEN_ELECTION_PRECENT  OTHER_POL_CMTE_CONTRIB  \
# 0           NaN                   NaN               459603.99
# 1           NaN                   NaN                67074.61
# 2           NaN                   NaN               843200.00
# 3           NaN                   NaN                    0.00
# 4           NaN                   NaN                    0.00
# 5           NaN                   NaN               828775.00
# 6           NaN                   NaN                11500.00
# 7           NaN                   NaN                    0.00
# 8           NaN                   NaN                    0.00
# 9           NaN                   NaN               660800.00
#
#    POL_PTY_CONTRIB  CVG_END_DT  INDIV_REFUNDS CMTE_REFUNDS
# 0              0.0    12/31/16        2250.00      3000.00
# 1           5000.0    12/31/16         884.01         0.00
# 2              0.0    12/31/16        1100.00         0.00
# 3              0.0     4/14/16           0.00         0.00
# 4              0.0    11/16/16           0.00         0.00
# 5              0.0    12/31/16       17550.00      4283.03
# 6              0.0     9/30/16        1845.00         0.00
# 7              0.0     4/15/16           0.00         0.00
# 8              0.0    12/31/16           0.00         0.00
# 9          14850.0    12/31/16        1000.00       200.00
#
# [10 rows x 31 columns]

# %%
df16.shape
# Out:
# (1898, 31)

# %%
df16.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# TTL_RECEIPTS              float64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT      float64
# SPEC_ELECTION             float64
# PRIM_ELECTION             float64
# RUN_ELECTION              float64
# GEN_ELECTION              float64
# GEN_ELECTION_PRECENT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# dtype: object

# %%
frames = [df18, df16]
result = pd.concat(frames, sort=False)

# %%
result.shape
# Out:
# (4577, 31)

# %%
result.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# TTL_RECEIPTS              float64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT      float64
# SPEC_ELECTION             float64
# PRIM_ELECTION             float64
# RUN_ELECTION              float64
# GEN_ELECTION              float64
# GEN_ELECTION_PRECENT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# dtype: object

# %%
result.describe(include='all')
# Out:
#           CAND_ID CAND_SURNAME CAND_FIRSTNAME CAND_ICI       PTY_CD  \
# count        4577         4577           4574     4509  4577.000000
# unique       3903         2856           2822        3          NaN
# top     H6AZ01199        SMITH           JOHN        C          NaN
# freq            2           32             46     2254          NaN
# mean          NaN          NaN            NaN      NaN     1.644964
# std           NaN          NaN            NaN      NaN     0.665073
# min           NaN          NaN            NaN      NaN     1.000000
# 25%           NaN          NaN            NaN      NaN     1.000000
# 50%           NaN          NaN            NaN      NaN     2.000000
# 75%           NaN          NaN            NaN      NaN     2.000000
# max           NaN          NaN            NaN      NaN     3.000000
#
#        CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH      TTL_DISB  \
# count                  4575  4.577000e+03     4.577000e+03  4.577000e+03
# unique                   32           NaN              NaN           NaN
# top                     DEM           NaN              NaN           NaN
# freq                   2113           NaN              NaN           NaN
# mean                    NaN  1.377729e+06     1.222638e+05  1.355787e+06
# std                     NaN  1.137490e+07     3.159024e+06  1.128689e+07
# min                     NaN  0.000000e+00     0.000000e+00 -1.268564e+04
# 25%                     NaN  1.531121e+04     0.000000e+00  1.512129e+04
# 50%                     NaN  1.206493e+05     0.000000e+00  1.203657e+05
# 75%                     NaN  9.960337e+05     0.000000e+00  9.185363e+05
# max                     NaN  5.856696e+08     1.607600e+08  5.853463e+08
#
#         TRANS_TO_AUTH  ...  SPEC_ELECTION  PRIM_ELECTION  RUN_ELECTION  \
# count    4.577000e+03  ...            0.0            0.0           0.0
# unique            NaN  ...            NaN            NaN           NaN
# top               NaN  ...            NaN            NaN           NaN
# freq              NaN  ...            NaN            NaN           NaN
# mean     8.471692e+03  ...            NaN            NaN           NaN
# std      9.397681e+04  ...            NaN            NaN           NaN
# min      0.000000e+00  ...            NaN            NaN           NaN
# 25%      0.000000e+00  ...            NaN            NaN           NaN
# 50%      0.000000e+00  ...            NaN            NaN           NaN
# 75%      0.000000e+00  ...            NaN            NaN           NaN
# max      3.642535e+06  ...            NaN            NaN           NaN
#
#         GEN_ELECTION  GEN_ELECTION_PRECENT  OTHER_POL_CMTE_CONTRIB  \
# count            0.0                   0.0            4.577000e+03
# unique           NaN                   NaN                     NaN
# top              NaN                   NaN                     NaN
# freq             NaN                   NaN                     NaN
# mean             NaN                   NaN            2.120677e+05
# std              NaN                   NaN            4.668144e+05
# min              NaN                   NaN            0.000000e+00
# 25%              NaN                   NaN            0.000000e+00
# 50%              NaN                   NaN            5.000000e+02
# 75%              NaN                   NaN            1.792500e+05
# max              NaN                   NaN            4.134430e+06
#
#         POL_PTY_CONTRIB  CVG_END_DT  INDIV_REFUNDS  CMTE_REFUNDS
# count       4577.000000        4577   4.577000e+03  4.577000e+03
# unique              NaN         475            NaN           NaN
# top                 NaN    12/31/18            NaN           NaN
# freq                NaN        1586            NaN           NaN
# mean        1429.913612         NaN   2.144566e+04  2.761844e+03
# std         9834.036813         NaN   1.687302e+05  2.615689e+04
# min            0.000000         NaN  -3.544889e+05 -2.000000e+03
# 25%            0.000000         NaN   0.000000e+00  0.000000e+00
# 50%            0.000000         NaN   5.000000e+00  0.000000e+00
# 75%            0.000000         NaN   6.100000e+03  0.000000e+00
# max       449200.000000         NaN   5.994031e+06  1.025588e+06
#
# [11 rows x 31 columns]

# %%
del result['SPEC_ELECTION']
del result['PRIM_ELECTION']
del result['RUN_ELECTION']
del result['GEN_ELECTION']
del result['GEN_ELECTION_PRECENT']

# %%
result.shape
# Out:
# (4577, 26)

# %%
pd.to_datetime(result['CVG_END_DT'])
# Out:
# 0      2018-12-31
# 1      2018-12-31
# 2      2018-12-31
# 3      2018-12-31
# 4      2018-12-31
#           ...
# 1893   2016-09-30
# 1894   2016-09-30
# 1895   2016-12-31
# 1896   2016-12-31
# 1897   2016-10-01
# Name: CVG_END_DT, Length: 4577, dtype: datetime64[ns]

# %%
result.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# TTL_RECEIPTS              float64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# dtype: object

# %%
result['YEAR'] = pd.DatetimeIndex(result['CVG_END_DT']).year

# %%
result.columns
# Out:
# Index(['CAND_ID', 'CAND_SURNAME', 'CAND_FIRSTNAME', 'CAND_ICI', 'PTY_CD',
#        'CAND_PTY_AFFILIATION', 'TTL_RECEIPTS', 'TRANS_FROM_AUTH', 'TTL_DISB',
#        'TRANS_TO_AUTH', 'COH_BOP', 'COH_COP', 'CAND_CONTRIB', 'CAND_LOANS',
#        'OTHER_LOANS', 'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY',
#        'TTL_INDIV_CONTRIB', 'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT',
#        'OTHER_POL_CMTE_CONTRIB', 'POL_PTY_CONTRIB', 'CVG_END_DT',
#        'INDIV_REFUNDS', 'CMTE_REFUNDS', 'YEAR'],
#       dtype='object')

# %%
result.head()
# Out:
#      CAND_ID CAND_SURNAME CAND_FIRSTNAME CAND_ICI  PTY_CD  \
# 0  H8AK00132        SHEIN        DIMITRI        C       1
# 1  H6AK00045        YOUNG       DONALD E        I       2
# 2  H8AK01031       NELSON    THOMAS JOHN        C       2
# 3  H8AK00140       GALVIN          ALYSE        C       3
# 4  H8AL01066      KENNEDY     ROBERT JR.        C       1
#
#   CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  \
# 0                  DEM     209916.04              0.0   209574.16
# 1                  REP    1234680.31              0.0  1387687.05
# 2                  REP       9288.48              0.0     8821.97
# 3                  IND    1949643.68            154.7  1943398.59
# 4                  DEM     166845.21              0.0   166845.21
#
#    TRANS_TO_AUTH  ...  DEBTS_OWED_BY  TTL_INDIV_CONTRIB  CAND_OFFICE_ST  \
# 0            0.0  ...         367.52           58188.98              AK
# 1            0.0  ...           0.00          670374.33              AK
# 2            0.0  ...           0.00            7100.05              AK
# 3            0.0  ...           0.00         1809591.38              AK
# 4            0.0  ...           0.00           39095.21              AL
#
#    CAND_OFFICE_DISTRICT  OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  CVG_END_DT  \
# 0                   0.0                    0.00              0.0    12/31/18
# 1                   0.0               559861.90              0.0    12/31/18
# 2                   0.0                    0.00              0.0    12/31/18
# 3                   0.0               114833.97              0.0    12/31/18
# 4                   1.0                 7750.00              0.0    12/31/18
#
#    INDIV_REFUNDS  CMTE_REFUNDS  YEAR
# 0           0.00           0.0  2018
# 1        2700.00         500.0  2018
# 2         600.00           0.0  2018
# 3        8166.36           0.0  2018
# 4           0.00           0.0  2018
#
# [5 rows x 27 columns]

# %%
result = result.rename(columns={'TTL_RECEIPTS': 'AMOUNT'})

# %%
result.head()
# Out:
#      CAND_ID CAND_SURNAME CAND_FIRSTNAME CAND_ICI  PTY_CD  \
# 0  H8AK00132        SHEIN        DIMITRI        C       1
# 1  H6AK00045        YOUNG       DONALD E        I       2
# 2  H8AK01031       NELSON    THOMAS JOHN        C       2
# 3  H8AK00140       GALVIN          ALYSE        C       3
# 4  H8AL01066      KENNEDY     ROBERT JR.        C       1
#
#   CAND_PTY_AFFILIATION      AMOUNT  TRANS_FROM_AUTH    TTL_DISB  \
# 0                  DEM   209916.04              0.0   209574.16
# 1                  REP  1234680.31              0.0  1387687.05
# 2                  REP     9288.48              0.0     8821.97
# 3                  IND  1949643.68            154.7  1943398.59
# 4                  DEM   166845.21              0.0   166845.21
#
#    TRANS_TO_AUTH  ...  DEBTS_OWED_BY  TTL_INDIV_CONTRIB  CAND_OFFICE_ST  \
# 0            0.0  ...         367.52           58188.98              AK
# 1            0.0  ...           0.00          670374.33              AK
# 2            0.0  ...           0.00            7100.05              AK
# 3            0.0  ...           0.00         1809591.38              AK
# 4            0.0  ...           0.00           39095.21              AL
#
#    CAND_OFFICE_DISTRICT  OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  CVG_END_DT  \
# 0                   0.0                    0.00              0.0    12/31/18
# 1                   0.0               559861.90              0.0    12/31/18
# 2                   0.0                    0.00              0.0    12/31/18
# 3                   0.0               114833.97              0.0    12/31/18
# 4                   1.0                 7750.00              0.0    12/31/18
#
#    INDIV_REFUNDS  CMTE_REFUNDS  YEAR
# 0           0.00           0.0  2018
# 1        2700.00         500.0  2018
# 2         600.00           0.0  2018
# 3        8166.36           0.0  2018
# 4           0.00           0.0  2018
#
# [5 rows x 27 columns]

# %%
result.columns
# Out:
# Index(['CAND_ID', 'CAND_SURNAME', 'CAND_FIRSTNAME', 'CAND_ICI', 'PTY_CD',
#        'CAND_PTY_AFFILIATION', 'AMOUNT', 'TRANS_FROM_AUTH', 'TTL_DISB',
#        'TRANS_TO_AUTH', 'COH_BOP', 'COH_COP', 'CAND_CONTRIB', 'CAND_LOANS',
#        'OTHER_LOANS', 'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY',
#        'TTL_INDIV_CONTRIB', 'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT',
#        'OTHER_POL_CMTE_CONTRIB', 'POL_PTY_CONTRIB', 'CVG_END_DT',
#        'INDIV_REFUNDS', 'CMTE_REFUNDS', 'YEAR'],
#       dtype='object')

# %%
result = result.rename(columns={'TTL_RECEIPTS ': 'AMOUNT'})

# %%
result.head()
# Out:
#      CAND_ID CAND_SURNAME CAND_FIRSTNAME CAND_ICI  PTY_CD  \
# 0  H8AK00132        SHEIN        DIMITRI        C       1
# 1  H6AK00045        YOUNG       DONALD E        I       2
# 2  H8AK01031       NELSON    THOMAS JOHN        C       2
# 3  H8AK00140       GALVIN          ALYSE        C       3
# 4  H8AL01066      KENNEDY     ROBERT JR.        C       1
#
#   CAND_PTY_AFFILIATION      AMOUNT  TRANS_FROM_AUTH    TTL_DISB  \
# 0                  DEM   209916.04              0.0   209574.16
# 1                  REP  1234680.31              0.0  1387687.05
# 2                  REP     9288.48              0.0     8821.97
# 3                  IND  1949643.68            154.7  1943398.59
# 4                  DEM   166845.21              0.0   166845.21
#
#    TRANS_TO_AUTH  ...  DEBTS_OWED_BY  TTL_INDIV_CONTRIB  CAND_OFFICE_ST  \
# 0            0.0  ...         367.52           58188.98              AK
# 1            0.0  ...           0.00          670374.33              AK
# 2            0.0  ...           0.00            7100.05              AK
# 3            0.0  ...           0.00         1809591.38              AK
# 4            0.0  ...           0.00           39095.21              AL
#
#    CAND_OFFICE_DISTRICT  OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  CVG_END_DT  \
# 0                   0.0                    0.00              0.0    12/31/18
# 1                   0.0               559861.90              0.0    12/31/18
# 2                   0.0                    0.00              0.0    12/31/18
# 3                   0.0               114833.97              0.0    12/31/18
# 4                   1.0                 7750.00              0.0    12/31/18
#
#    INDIV_REFUNDS  CMTE_REFUNDS  YEAR
# 0           0.00           0.0  2018
# 1        2700.00         500.0  2018
# 2         600.00           0.0  2018
# 3        8166.36           0.0  2018
# 4           0.00           0.0  2018
#
# [5 rows x 27 columns]

# %%
result.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# AMOUNT                    float64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# YEAR                        int64
# dtype: object

# %%
result['AMOUNT'] = result['AMOUNT'].astype('int64', copy=False)

# %%
result.dtypes
# Out:
# CAND_ID                    object
# CAND_SURNAME               object
# CAND_FIRSTNAME             object
# CAND_ICI                   object
# PTY_CD                      int64
# CAND_PTY_AFFILIATION       object
# AMOUNT                      int64
# TRANS_FROM_AUTH           float64
# TTL_DISB                  float64
# TRANS_TO_AUTH             float64
# COH_BOP                   float64
# COH_COP                   float64
# CAND_CONTRIB              float64
# CAND_LOANS                float64
# OTHER_LOANS               float64
# CAND_LOAN_REPAY           float64
# OTHER_LOAN_REPAY          float64
# DEBTS_OWED_BY             float64
# TTL_INDIV_CONTRIB         float64
# CAND_OFFICE_ST             object
# CAND_OFFICE_DISTRICT      float64
# OTHER_POL_CMTE_CONTRIB    float64
# POL_PTY_CONTRIB           float64
# CVG_END_DT                 object
# INDIV_REFUNDS             float64
# CMTE_REFUNDS              float64
# YEAR                        int64
# dtype: object

# %%
result['AMOUNT'].sum()
# Out:
# 6305862129

# %%
result.groupby('CAND_ID')['AMOUNT'].sum().sort_values(ascending=False).head(10)
# Out:
# CAND_ID
# P00003392    591607695
# P80001571    418216720
# P60007168    237757853
# P60006111     94661493
# S8FL00273     85231716
# H2TX16185     80935492
# S8TX00285     80344836
# P60005915     65106183
# P60006723     48671063
# S8NJ00509     39236111
# Name: AMOUNT, dtype: int64

# %%
result.loc[result['CAND_ID'] == "P00003392"]
# Out:
#         CAND_ID CAND_SURNAME                           CAND_FIRSTNAME  \
# 2289  P00003392      CLINTON   HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1476  P00003392      CLINTON   HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#      CAND_ICI  PTY_CD CAND_PTY_AFFILIATION     AMOUNT  TRANS_FROM_AUTH  \
# 2289        O       1                  DEM    5938097     8.132212e+04
# 1476        O       1                  DEM  585669598     1.607600e+08
#
#          TTL_DISB  TRANS_TO_AUTH  ...  DEBTS_OWED_BY  TTL_INDIV_CONTRIB  \
# 2289    5645941.0            0.0  ...            0.0                0.0
# 1476  585346281.4            0.0  ...          182.5        405664230.5
#
#       CAND_OFFICE_ST  CAND_OFFICE_DISTRICT  OTHER_POL_CMTE_CONTRIB  \
# 2289               0                   0.0                    0.00
# 1476               0                   0.0              1793640.85
#
#       POL_PTY_CONTRIB  CVG_END_DT  INDIV_REFUNDS  CMTE_REFUNDS  YEAR
# 2289              0.0    12/31/18       35437.76           0.0  2018
# 1476          20039.3    12/31/16     5994030.76        8450.0  2016
#
# [2 rows x 27 columns]

# %%
result['CAND_PTY_AFFILIATION'].value_counts()
# Out:
# DEM    2113
# REP    1976
# IND     185
# LIB      87
# GRE      39
# NNE      25
# NPA      25
# OTH      23
# DFL      21
# UNK      21
# UN       14
# CON       9
# W         6
# NOP       5
# IDP       4
# NON       3
# PPY       2
# SEP       2
# AMP       2
# PFD       1
# MTP       1
# PPT       1
# CST       1
# N         1
# GOP       1
# NPP       1
# MPP       1
# UNI       1
# REF       1
# PBP       1
# GWP       1
# REC       1
# Name: CAND_PTY_AFFILIATION, dtype: int64

# %%
result.groupby('CAND_PTY_AFFILIATION')['AMOUNT'].sum().sort_values(ascending=False)
# Out:
# CAND_PTY_AFFILIATION
# DEM    3398807130
# REP    2794089819
# IND      39189311
# DFL      24185721
# LIB      14436148
# GRE      13833078
# UNK      11064289
# CON       4355747
# OTH       2684459
# NPP        941389
# NPA        779872
# NNE        403703
# UNI        257503
# GOP        253800
# UN         109604
# NOP         99971
# AMP         79145
# NON         56109
# REC         50106
# PFD         31408
# PPY         28712
# SEP         23990
# MPP         22700
# REF         17014
# W           15554
# IDP          4882
# PPT          2451
# MTP          2230
# CST            15
# N               0
# PBP             0
# GWP             0
# Name: AMOUNT, dtype: int64

# %%
parties = result.groupby('CAND_PTY_AFFILIATION')['AMOUNT'].sum().sort_values(ascending=False)

parties.plot(kind="bar")

# %%
result.groupby('YEAR')['AMOUNT'].sum().sort_values(ascending=False)
# Out:
# YEAR
# 2016    3243458193
# 2018    3046386891
# 2017       8168664
# 2015       7747680
# 2019        100701
# Name: AMOUNT, dtype: int64

# %%
result.groupby(['CAND_PTY_AFFILIATION', 'YEAR'])['AMOUNT'].sum().unstack().sort_values(2019).head(10)
# Out:
# YEAR                       2015          2016       2017          2018  \
# CAND_PTY_AFFILIATION
# NPA                         NaN  8.563200e+04    29182.0  6.650580e+05
# IND                      8846.0  8.456949e+06    19153.0  3.070361e+07
# DEM                   2798253.0  1.652913e+09  3173734.0  1.739904e+09
# REP                   4880372.0  1.540867e+09  4890247.0  1.243370e+09
# AMP                         NaN  8.216000e+03        NaN  7.092900e+04
# CON                         NaN  8.373800e+04        0.0  4.272009e+06
# CST                         NaN  1.500000e+01        NaN           NaN
# DFL                         NaN  7.524353e+06    14120.0  1.664725e+07
# GOP                         NaN           NaN        NaN  2.538000e+05
# GRE                     14241.0  1.139837e+07     5090.0  2.415377e+06
#
# YEAR                     2019
# CAND_PTY_AFFILIATION
# NPA                       0.0
# IND                     749.0
# DEM                   17740.0
# REP                   82212.0
# AMP                       NaN
# CON                       NaN
# CST                       NaN
# DFL                       NaN
# GOP                       NaN
# GRE                       NaN

# %%
annual_received = result.groupby(['CAND_PTY_AFFILIATION', 'YEAR'])['AMOUNT'].sum().unstack().sort_values(2019).head(10)
annual_received.plot(kind="bar")

# %%
labels = 'DEMS', 'REP', 'IND',
sizes = [3398092185, 2793745636, 39175823]
explode = (0.1, 0.0, 0, )  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
